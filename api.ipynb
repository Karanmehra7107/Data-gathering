# %%
#1.data gathering 
  #1.api, 2.web scraping, 3.database
#api: open TMDB, login, in settings generate api key and copy key link, another tab search tmbd.api
#search for movies, getpopular, try, copy the link and add api key and enter file openes in jason format
#open json viwesr to iew structure of data.


import requests
import pandas as pd

# %%
requests.get('https://api.themoviedb.org/3/movie/popular?api_key=f0203d8343eb78a426cc4c39d4d988b3&language=en-US&page=1')
# Out:
# <Response [200]>

# %%
response= requests.get('https://api.themoviedb.org/3/movie/popular?api_key=f0203d8343eb78a426cc4c39d4d988b3&language=en-US&page=1').json()

# %%
response
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/jeAQdDX9nguP6YOX6QSWKDPkbBo.jpg',
#    'genre_ids': [28, 14, 878],
#    'id': 590706,
#    'original_language': 'en',
#    'original_title': 'Jiu Jitsu',
#    'overview': 'Every six years, an ancient order of jiu-jitsu fighters joins forces to battle a vicious race of alien invaders. But when a celebrated war hero goes down in defeat, the fate of the planet and mankind hangs in the balance.',
#    'popularity': 2179.557,
#    'poster_path': '/eLT8Cu357VOwBVTitkmlDEg32Fs.jpg',
#    'release_date': '2020-11-20',
#    'title': 'Jiu Jitsu',
#    'video': False,
#    'vote_average': 5.8,
#    'vote_count': 153},
#   {'adult': False,
#    'backdrop_path': '/ckfwfLkl0CkafTasoRw5FILhZAS.jpg',
#    'genre_ids': [28, 35, 14],
#    'id': 602211,
#    'original_language': 'en',
#    'original_title': 'Fatman',
# ...

# %%
#stratigy: 
d={'name':['Rahul','mohit'], 'age':[21,33]}
data=pd.DataFrame(d)
data
# Out:
#     name  age
# 0  Rahul   21
# 1  mohit   33

# %%
## creating empty lists

# %%
popularity=[]
vote_count=[]
original_language=[]
title=[]
overview=[]
release_date=[]
for i in response['results']:
    popularity.append(i['popularity'])
    vote_count.append(i['vote_count'])
    original_language.append(i['original_language'])
    title.append(i['title'])
    
    overview.append(i['overview'])
    release_date.append(i['release_date'])
d={'title':title, 'overview':overview, 'original_language':original_language, 'release_date':release_date, 'vote_count':vote_count, 'popularity':popularity}
    
df=pd.DataFrame(d)
df
# Out:
#                                  title  \
# 0                            Jiu Jitsu
# 1                               Fatman
# 2                    The Craft: Legacy
# 3                     Battlefield 2025
# 4                          Chick Fight
# 5                      The Dalton Gang
# 6                            Hard Kill
# 7                               Wander
# 8                          Godmothered
# 9                        Bone Tomahawk
# 10                               Tenet
# 11                          Rogue City
# 12                        Honest Thief
# 13            Roald Dahl's The Witches
# 14                           Greenland
# 15             Welcome to Sudden Death
# 16                           Peninsula
# 17  The Christmas Chronicles: Part Two
# 18                               Mulan
# 19             Angela's Christmas Wish
#
#                                              overview original_language  \
# ...

# %%
# first page containing 20 rows

# %%
    final=pd.DataFrame()
    for j in range(1,501):
        response= requests.get('https://api.themoviedb.org/3/movie/popular?api_key=f0203d8343eb78a426cc4c39d4d988b3&language=en-US&page={}'.format(j)).json()
    popularity=[]
    vote_count=[]
    original_language=[]
    title=[]
    overview=[]
    release_date=[]
    for i in response['results']:
        popularity.append(i['popularity'])
        vote_count.append(i['vote_count'])
        original_language.append(i['original_language'])
        title.append(i['title'])

        overview.append(i['overview'])
        release_date.append(i['release_date'])
    d={'title':title, 'overview':overview, 'original_language':original_language, 'release_date':release_date, 'vote_count':vote_count, 'popularity':popularity}

    df=pd.DataFrame(d)
    df
    final=final.append(df, ignore_index=True)

# %%
final.shape
# Out:
# (20, 6)

# %%
final
# Out:
#                                   title  \
# 0                                Greedy
# 1               Yes, No, or Maybe Half?
# 2                                  Maze
# 3                    Dying of the Light
# 4                            Aftershock
# 5                    Days of Being Wild
# 6                       Circus of Books
# 7                      Drinking Buddies
# 8                            Dirty Work
# 9                             The Nines
# 10                 Identifying Features
# 11             Every Thing Will Be Fine
# 12                       The Key to Sex
# 13                      Wait Until Dark
# 14           Nothing Left to Do but Cry
# 15            Burn the Stage: The Movie
# 16                        Heroes Wanted
# 17  Green Street Hooligans: Underground
# 18            A Good Old Fashioned Orgy
# 19                        Eye on Juliet
#
#                                              overview original_language  \
# ...

# %%
final.to_csv('movies.csv')
